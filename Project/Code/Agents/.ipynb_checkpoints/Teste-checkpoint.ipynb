# %%
import IPython
import chess
from IPython.display import display, HTML, clear_output
import AgentsPlayGround
from AgentsPlayGround import AgentsPlayGround
from ipywidgets import interact, fixed
from board import SimpleBoard

#display(HTML("<style>div.output_scroll { height: 44em; }</style>"))

jeffrey = AgentsPlayGround()
jeffrey.load_network_tuner()
jeffrey.kingsDecision.network.summary()
#jeffrey.loadStorage()
jeffrey.loadWeights()

correctAgent = []
correctMove = []
x = 10

for i in range(x):
    try:
        jeffrey.testAllAgentsWKingsDecision()
        correctAgent += jeffrey.correctAgent
        correctMove += jeffrey.correctMoveWhenCorrectAgent
    except:
        x += 1
print(correctAgent)

print(correctMove)

if len(correctAgent) > 0:
    print("\n\nKingsDecision chose the agents correctly {:.1f}%".format(sum(correctAgent) / len(correctAgent)))
if len(correctMove) > 0:
    print("Agents chose the move correctly {:.1f}% when KingDecision chose the Agent correctly".format(sum(correctMove) / len(correctMove)))
        
print("\n\nx is {}".format(x))
#jeffrey.testAllAgentsAgainstRandom()

'''
for agent in jeffrey.Agents:
    if agent !=None:
        x = 0
        print(type(agent))
        agent.loadStorage()
        for i in range(100):
            if agent.predict(agent.train_x[i]).argmax() == agent.train_y[i]:
                x = x + 1
        print(x / 100)
'''
        


"""
board = jeffrey.board
board_copy = SimpleBoard()
copied_moves = 0

@interact(m=(0,len(board.move_stack)), board=fixed(board))
def show_board_at_move(m=0, board=board):
    global board_copy, copied_moves
    if copied_moves > m:
        for i in range(copied_moves - m):
            board_copy.pop()
    elif copied_moves < m:
        for move in board.move_stack[copied_moves:m]:
            board_copy.push(move)
    copied_moves = m
    return board_copy
"""
# Out:
# Using TensorFlow backend.
# INFO:tensorflow:Reloading Oracle from existing project ./tunner/KingsDecision/KingsDecision/oracle.json
# INFO:tensorflow:Reloading Tuner from ./tunner/KingsDecision/KingsDecision/tuner0.json
# INFO:tensorflow:Reloading Oracle from existing project ./tunner/Pawns/oracle.json
# INFO:tensorflow:Reloading Tuner from ./tunner/Pawns/tuner0.json
# {'activation': 'sigmoid', 'num_layers': 2, 'optimizer': 'adam', 'units_0': 10, 'units_1': 6, 'units_2': 4, 'tuner/epochs': 7, 'tuner/initial_epoch': 0, 'tuner/bracket': 1, 'tuner/round': 0}
# INFO:tensorflow:Reloading Oracle from existing project ./tunner/Horses/oracle.json
# INFO:tensorflow:Reloading Tuner from ./tunner/Horses/tuner0.json
# INFO:tensorflow:Reloading Oracle from existing project ./tunner/Bishops/oracle.json
# INFO:tensorflow:Reloading Tuner from ./tunner/Bishops/tuner0.json
# INFO:tensorflow:Reloading Oracle from existing project tunner/Rooks/oracle.json
# INFO:tensorflow:Reloading Tuner from tunner/Rooks/tuner0.json
# {'activation': 'sigmoid', 'num_layers': 1, 'optimizer': 'adam', 'units_0': 6, 'units_1': 8, 'units_2': 10, 'units_3': 7, 'tuner/epochs': 20, 'tuner/initial_epoch': 0, 'tuner/bracket': 0, 'tuner/round': 0}
# INFO:tensorflow:Reloading Oracle from existing project ./tunner/Queen/oracle.json
# INFO:tensorflow:Reloading Tuner from ./tunner/Queen/tuner0.json
# INFO:tensorflow:Reloading Oracle from existing project ./tunner/King/oracle.json
# INFO:tensorflow:Reloading Tuner from ./tunner/King/tuner0.json
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# flatten (Flatten)            (None, 32)                0
# _________________________________________________________________
# dense (Dense)                (None, 480)               15840
# _________________________________________________________________
# dense_1 (Dense)              (None, 64)                30784
# _________________________________________________________________
# dense_2 (Dense)              (None, 128)               8320
# _________________________________________________________________
# dense_3 (Dense)              (None, 128)               16512
# _________________________________________________________________
# dense_4 (Dense)              (None, 16)                2064
# =================================================================
# Total params: 73,520
# Trainable params: 73,520
# Non-trainable params: 0
# _________________________________________________________________
# WARNING:tensorflow:Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow.python.keras.layers.core.Dense object at 0x145f508e0> and <tensorflow.python.keras.layers.core.Dense object at 0x145f50400>).
# WARNING:tensorflow:Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow.python.keras.layers.core.Dense object at 0x145f50400> and <tensorflow.python.keras.layers.core.Dense object at 0x10c8b9d30>).
# WARNING:tensorflow:Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow.python.keras.layers.core.Dense object at 0x10c8d40d0> and <tensorflow.python.keras.layers.core.Dense object at 0x145e9ebe0>).
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# flatten (Flatten)            (None, 32)                0
# _________________________________________________________________
# dense (Dense)                (None, 160)               5280
# _________________________________________________________________
# dense_1 (Dense)              (None, 480)               77280
# _________________________________________________________________
# dense_2 (Dense)              (None, 56)                26936
# =================================================================
# Total params: 109,496
# Trainable params: 109,496
# Non-trainable params: 0
# _________________________________________________________________
# None
#
#
# KingsDecision chose the agents correctly 65.7%
# Agents chose the move correctly 17.4% when KingDecision chose the Agent correctly
#
#
# KingsDecision chose the agents correctly 36.5%
# Agents chose the move correctly 19.4% when KingDecision chose the Agent correctly
#
#
# KingsDecision chose the agents correctly 13.4%
# Agents chose the move correctly 55.6% when KingDecision chose the Agent correctly
#
#
# KingsDecision chose the agents correctly 72.7%
# Agents chose the move correctly 11.1% when KingDecision chose the Agent correctly
#
#
# KingsDecision chose the agents correctly 57.9%
# Agents chose the move correctly 39.4% when KingDecision chose the Agent correctly
#
#
# KingsDecision chose the agents correctly 47.1%
# Agents chose the move correctly 17.5% when KingDecision chose the Agent correctly
#
#
# KingsDecision chose the agents correctly 23.3%
# Agents chose the move correctly 28.6% when KingDecision chose the Agent correctly
#
#
# KingsDecision chose the agents correctly 31.6%
# Agents chose the move correctly 16.7% when KingDecision chose the Agent correctly
#
#
# x is 20
# '\nboard = jeffrey.board\nboard_copy = SimpleBoard()\ncopied_moves = 0\n\n@interact(m=(0,len(board.move_stack)), board=fixed(board))\ndef show_board_at_move(m=0, board=board):\n    global board_copy, copied_moves\n    if copied_moves > m:\n        for i in range(copied_moves - m):\n            board_copy.pop()\n    elif copied_moves < m:\n        for move in board.move_stack[copied_moves:m]:\n            board_copy.push(move)\n    copied_moves = m\n    return board_copy\n'
