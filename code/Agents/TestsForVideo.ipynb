# %%
import IPython
import chess
from IPython.display import display, HTML, clear_output
import AgentsPlayGround
from AgentsPlayGround import AgentsPlayGround
from ipywidgets import interact, fixed
from board import SimpleBoard

#display(HTML("<style>div.output_scroll { height: 44em; }</style>"))

jeffrey = AgentsPlayGround()
jeffrey.load_network_tuner()
jeffrey.loadWeights()



jeffrey.testAllAgentsWKingsDecision()
   


board = jeffrey.board
board_copy = SimpleBoard()
copied_moves = 0

@interact(m=(0,len(board.move_stack)), board=fixed(board))
def show_board_at_move(m=0, board=board):
    global board_copy, copied_moves
    if copied_moves > m:
        for i in range(copied_moves - m):
            board_copy.pop()
    elif copied_moves < m:
        for move in board.move_stack[copied_moves:m]:
            board_copy.push(move)
    copied_moves = m
    return board_copy
# Out:
# INFO:tensorflow:Reloading Oracle from existing project ./tunner/KingsDecision/KingsDecision/oracle.json
# INFO:tensorflow:Reloading Tuner from ./tunner/KingsDecision/KingsDecision/tuner0.json
# INFO:tensorflow:Reloading Oracle from existing project ./tunner/Pawns/oracle.json
# INFO:tensorflow:Reloading Tuner from ./tunner/Pawns/tuner0.json
# INFO:tensorflow:Reloading Oracle from existing project ./tunner/Horses/oracle.json
# INFO:tensorflow:Reloading Tuner from ./tunner/Horses/tuner0.json
# INFO:tensorflow:Reloading Oracle from existing project ./tunner/Bishops/oracle.json
# INFO:tensorflow:Reloading Tuner from ./tunner/Bishops/tuner0.json
# INFO:tensorflow:Reloading Oracle from existing project tunner/Rooks/oracle.json
# INFO:tensorflow:Reloading Tuner from tunner/Rooks/tuner0.json
# {'activation': 'sigmoid', 'num_layers': 1, 'optimizer': 'adam', 'units_0': 6, 'units_1': 8, 'units_2': 10, 'units_3': 7, 'tuner/epochs': 20, 'tuner/initial_epoch': 0, 'tuner/bracket': 0, 'tuner/round': 0}
# INFO:tensorflow:Reloading Oracle from existing project ./tunner/Queen/oracle.json
# INFO:tensorflow:Reloading Tuner from ./tunner/Queen/tuner0.json
# INFO:tensorflow:Reloading Oracle from existing project ./tunner/King/oracle.json
# INFO:tensorflow:Reloading Tuner from ./tunner/King/tuner0.json
# WARNING:tensorflow:Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow.python.keras.layers.core.Dense object at 0x14a2d4700> and <tensorflow.python.keras.layers.core.Dense object at 0x14a2d4fa0>).
# WARNING:tensorflow:Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow.python.keras.layers.core.Dense object at 0x14a2d4fa0> and <tensorflow.python.keras.layers.core.Dense object at 0x14a2d4640>).
# WARNING:tensorflow:Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow.python.keras.layers.core.Dense object at 0x14a1c87c0> and <tensorflow.python.keras.layers.core.Dense object at 0x14a1c8ac0>).
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# flatten (Flatten)            (None, 32)                0
# _________________________________________________________________
# dense (Dense)                (None, 160)               5280
# _________________________________________________________________
# dense_1 (Dense)              (None, 480)               77280
# _________________________________________________________________
# dense_2 (Dense)              (None, 56)                26936
# =================================================================
# Total params: 109,496
# Trainable params: 109,496
# Non-trainable params: 0
# _________________________________________________________________
# None
#
#
# ITERAÇÃO=0
# The King nominated <class 'Horses.Horses'> to play!
# 	 the <class 'Horses.Horses'> decided to play g1f3
# stockfish: b1c3
#
#
# ITERAÇÃO=1
#
#
# ITERAÇÃO=2
# The King nominated <class 'Horses.Horses'> to play!
# 	 the <class 'Horses.Horses'> decided to play b1c3
# stockfish: c2c3
#
#
# ITERAÇÃO=3
#
#
# ITERAÇÃO=4
# The King nominated <class 'Pawns.Pawns'> to play!
# 	 the <class 'Pawns.Pawns'> decided to play h2h3
# stockfish: d2d3
#
#
# ITERAÇÃO=5
#
#
# ITERAÇÃO=6
# The King nominated <class 'Pawns.Pawns'> to play!
# 	 the <class 'Pawns.Pawns'> decided to play h3h4
# stockfish: h3h4
#
#
# ITERAÇÃO=7
#
#
# ITERAÇÃO=8
# The King nominated <class 'Pawns.Pawns'> to play!
# 	 the <class 'Pawns.Pawns'> decided to play h4h5
# stockfish: h4h5
#
#
# ITERAÇÃO=9
#
#
# ITERAÇÃO=10
# The King nominated <class 'Pawns.Pawns'> to play!
# 	 the <class 'Pawns.Pawns'> decided to play h5a7
# stockfish: h5g6
# 		 the <class 'Pawns.Pawns'> chose an invalid play h5a7
# 	 the <class 'Pawns.Pawns'> decided to play h5g6
# stockfish: h5g6
#
#
# ITERAÇÃO=11
#
#
# ITERAÇÃO=12
# The King nominated <class 'Pawns.Pawns'> to play!
# 	 the <class 'Pawns.Pawns'> decided to play g6h7
# stockfish: h1h7
#
#
# ITERAÇÃO=13
#
#
# ITERAÇÃO=14
# The King nominated <class 'Horses.Horses'> to play!
# 	 the <class 'Horses.Horses'> decided to play f3e5
# stockfish: c3e4
#
#
# ITERAÇÃO=15
#
#
# ITERAÇÃO=16
# The King nominated <class 'Horses.Horses'> to play!
# 	 the <class 'Horses.Horses'> decided to play e5d7
# stockfish: e5f7
#
#
# ITERAÇÃO=17
#
#
# ITERAÇÃO=18
# The King nominated <class 'Rooks.Rooks'> to play!
# 	 the <class 'Rooks.Rooks'> decided to play a1d1
# stockfish: c3a4
# 		 the <class 'Rooks.Rooks'> chose an invalid play a1d1
# 	 the <class 'Rooks.Rooks'> decided to play h1h7
# stockfish: c3a4
# 		 the <class 'Rooks.Rooks'> chose an invalid play h1h7
# 	 the <class 'Rooks.Rooks'> decided to play a1a8
# stockfish: c3a4
# 		 the <class 'Rooks.Rooks'> chose an invalid play a1a8
# 	 the <class 'Rooks.Rooks'> decided to play h1h3
# stockfish: c3a4
#
#
# ITERAÇÃO=19
#
#
# ITERAÇÃO=20
# The King nominated <class 'Horses.Horses'> to play!
# 	 the <class 'Horses.Horses'> decided to play c3d5
# stockfish: g2h3
#
#
# ITERAÇÃO=21
#
#
# ITERAÇÃO=22
# The King nominated <class 'Horses.Horses'> to play!
# 	 the <class 'Horses.Horses'> decided to play d5c7
# stockfish: d5c7
#
#
# ITERAÇÃO=23
#
#
# ITERAÇÃO=24
# The King nominated <class 'Horses.Horses'> to play!
# 	 the <class 'Horses.Horses'> decided to play c7d9
# stockfish: c7a8
# 		 the <class 'Horses.Horses'> chose an invalid play c7d9
# 	 the <class 'Horses.Horses'> decided to play c7b5
# stockfish: c7a8
#
#
# ITERAÇÃO=25
#
#
# ITERAÇÃO=26
# The King nominated <class 'Horses.Horses'> to play!
# 	 the <class 'Horses.Horses'> decided to play b5a7
# stockfish: b5d6
#
#
# ITERAÇÃO=27
#
#
# ITERAÇÃO=28
# The King nominated <class 'Horses.Horses'> to play!
# 	 the <class 'Horses.Horses'> decided to play a7b9
# stockfish: a7c8
# 		 the <class 'Horses.Horses'> chose an invalid play a7b9
# 	 the <class 'Horses.Horses'> decided to play a7`5
# stockfish: a7c8
# 		 the <class 'Horses.Horses'> chose an invalid play a7`5
# 	 the <class 'Horses.Horses'> decided to play a7`9
# stockfish: a7c8
# 		 the <class 'Horses.Horses'> chose an invalid play a7`9
# 	 the <class 'Horses.Horses'> decided to play
# stockfish: a7c8
# 		 the <class 'Horses.Horses'> chose an invalid play
# 	 the <class 'Horses.Horses'> decided to play
# stockfish: a7c8
# 		 the <class 'Horses.Horses'> chose an invalid play
# 	 the <class 'Horses.Horses'> decided to play a7c8
# stockfish: a7c8
#
#
# ITERAÇÃO=29
#
#
# ITERAÇÃO=30
# The King nominated <class 'Horses.Horses'> to play!
# 	 the <class 'Horses.Horses'> decided to play c8b6
# stockfish: c8d6
#
#
# ITERAÇÃO=31
#
#
# ITERAÇÃO=32
# The King nominated <class 'Horses.Horses'> to play!
# 	 the <class 'Horses.Horses'> decided to play b6a8
# stockfish: b6c8
#
#
# ITERAÇÃO=33
#
#
# ITERAÇÃO=34
# The King nominated <class 'Horses.Horses'> to play!
# 	 the <class 'Horses.Horses'> decided to play a8`6
# stockfish: a8c7
# 		 the <class 'Horses.Horses'> chose an invalid play a8`6
# 	 the <class 'Horses.Horses'> decided to play a8b:
# stockfish: a8c7
# 		 the <class 'Horses.Horses'> chose an invalid play a8b:
# 	 the <class 'Horses.Horses'> decided to play
# stockfish: a8c7
# 		 the <class 'Horses.Horses'> chose an invalid play
# 	 the <class 'Horses.Horses'> decided to play a8`:
# stockfish: a8c7
# 		 the <class 'Horses.Horses'> chose an invalid play a8`:
# 	 the <class 'Horses.Horses'> decided to play
# stockfish: a8c7
# 		 the <class 'Horses.Horses'> chose an invalid play
# 	 the <class 'Horses.Horses'> decided to play
# stockfish: a8c7
# 		 the <class 'Horses.Horses'> chose an invalid play
# 	 the <class 'Horses.Horses'> decided to play
# stockfish: a8c7
# 		 the <class 'Horses.Horses'> chose an invalid play
# 	 the <class 'Horses.Horses'> decided to play a8c9
# stockfish: a8c7
# 		 the <class 'Horses.Horses'> chose an invalid play a8c9
# 	 the <class 'Horses.Horses'> decided to play
# stockfish: a8c7
# 		 the <class 'Horses.Horses'> chose an invalid play
# 	 the <class 'Horses.Horses'> decided to play
# stockfish: a8c7
# 		 the <class 'Horses.Horses'> chose an invalid play
# 	 the <class 'Horses.Horses'> decided to play a8_9
# stockfish: a8c7
# 		 the <class 'Horses.Horses'> chose an invalid play a8_9
# 	 the <class 'Horses.Horses'> decided to play a8c7
# stockfish: a8c7
#
#
# ITERAÇÃO=35
#
#
# ITERAÇÃO=36
# The King nominated <class 'Horses.Horses'> to play!
# 	 the <class 'Horses.Horses'> decided to play c7b5
# stockfish: d2d3
#
#
# ITERAÇÃO=37
#
#
# ITERAÇÃO=38
# The King nominated <class 'Horses.Horses'> to play!
# 	 the <class 'Horses.Horses'> decided to play b5a7
# stockfish: b5c3
#
#
# ITERAÇÃO=39
#
#
# ITERAÇÃO=40
# The King nominated <class 'Horses.Horses'> to play!
# 	 the <class 'Horses.Horses'> decided to play a7b9
# stockfish: e2e3
# 		 the <class 'Horses.Horses'> chose an invalid play a7b9
# 	 the <class 'Horses.Horses'> decided to play a7`5
# stockfish: e2e3
# 		 the <class 'Horses.Horses'> chose an invalid play a7`5
# 	 the <class 'Horses.Horses'> decided to play a7`9
# stockfish: e2e3
# 		 the <class 'Horses.Horses'> chose an invalid play a7`9
# 	 the <class 'Horses.Horses'> decided to play
# stockfish: e2e3
# 		 the <class 'Horses.Horses'> chose an invalid play
# 	 the <class 'Horses.Horses'> decided to play a7c8
# stockfish: e2e3
#
#
# ITERAÇÃO=41
#
#
# ITERAÇÃO=42
# The King nominated <class 'Horses.Horses'> to play!
# 	 the <class 'Horses.Horses'> decided to play c8b6
# stockfish: c8a7
#
#
# ITERAÇÃO=43
#
#
# ITERAÇÃO=44
# The King nominated <class 'Horses.Horses'> to play!
# 	 the <class 'Horses.Horses'> decided to play b6c8
# stockfish: b6d5
#
#
# ITERAÇÃO=45
#
#
# ITERAÇÃO=46
# The King nominated <class 'Horses.Horses'> to play!
# 	 the <class 'Horses.Horses'> decided to play c8b6
# stockfish: c8a7
#
#
# ITERAÇÃO=47
#
#
# ITERAÇÃO=48
# The King nominated <class 'Horses.Horses'> to play!
# 	 the <class 'Horses.Horses'> decided to play b6c8
# stockfish: b6d5
#
#
# ITERAÇÃO=49
#
#
# ITERAÇÃO=50
# The King nominated <class 'Horses.Horses'> to play!
# 	 the <class 'Horses.Horses'> decided to play c8b6
# stockfish: e2e3
#
#
# ITERAÇÃO=51
#
#
# ITERAÇÃO=52
# The King nominated <class 'Horses.Horses'> to play!
# 	 the <class 'Horses.Horses'> decided to play b6c8
# stockfish: e2e3
#
#
# ITERAÇÃO=53
#
#
# ITERAÇÃO=54
# The King nominated <class 'Horses.Horses'> to play!
# 	 the <class 'Horses.Horses'> decided to play c8b6
# stockfish: d2d3
#
#
# ITERAÇÃO=55
#
#
# ITERAÇÃO=56
# The King nominated <class 'Horses.Horses'> to play!
# 	 the <class 'Horses.Horses'> decided to play b6c8
# stockfish: a1b1
#
#
# ITERAÇÃO=57
#
#
# ITERAÇÃO=58
# The King nominated <class 'Horses.Horses'> to play!
# 	 the <class 'Horses.Horses'> decided to play c8b6
# stockfish: c8b6
#
#
# ITERAÇÃO=59
#
#
# ITERAÇÃO=60
# The King nominated <class 'Horses.Horses'> to play!
# 	 the <class 'Horses.Horses'> decided to play b6c8
# stockfish: e2e3
#
#
# ITERAÇÃO=61
#
#
# ITERAÇÃO=62
# The King nominated <class 'Horses.Horses'> to play!
# 	 the <class 'Horses.Horses'> decided to play c8b6
# stockfish: c8a7
#
#
# ITERAÇÃO=63
#
#
# ITERAÇÃO=64
# The King nominated <class 'Horses.Horses'> to play!
# 	 the <class 'Horses.Horses'> decided to play b6c8
# stockfish: b6a8
#
#
# ITERAÇÃO=65
#
#
# ITERAÇÃO=66
# The King nominated <class 'Horses.Horses'> to play!
# 	 the <class 'Horses.Horses'> decided to play c8b6
# stockfish: c8a7
#
#
# ITERAÇÃO=67
#
#
# ITERAÇÃO=68
# The King nominated <class 'Horses.Horses'> to play!
# 	 the <class 'Horses.Horses'> decided to play b6c8
# stockfish: b6d5
#
#
# ITERAÇÃO=69
#
#
# ITERAÇÃO=70
# The King nominated <class 'Horses.Horses'> to play!
# 	 the <class 'Horses.Horses'> decided to play c8b6
# stockfish: c8a7
#
#
# ITERAÇÃO=71
#
#
# ITERAÇÃO=72
# The King nominated <class 'Horses.Horses'> to play!
# 	 the <class 'Horses.Horses'> decided to play b6c8
# stockfish: b6d5
#
#
# ITERAÇÃO=73
#
#
# ITERAÇÃO=74
# The King nominated <class 'Horses.Horses'> to play!
# 	 the <class 'Horses.Horses'> decided to play c8b6
# stockfish: e2e3
#
#
# ITERAÇÃO=75
#
#
# ITERAÇÃO=76
# The King nominated <class 'Horses.Horses'> to play!
# 	 the <class 'Horses.Horses'> decided to play b6c8
# stockfish: b6c4
#
#
# ITERAÇÃO=77
#
#
# ITERAÇÃO=78
# The King nominated <class 'Horses.Horses'> to play!
# 	 the <class 'Horses.Horses'> decided to play c8b6
# stockfish: c8e7
#
#
# ITERAÇÃO=79
#
#
# ITERAÇÃO=80
# The King nominated <class 'Horses.Horses'> to play!
# 	 the <class 'Horses.Horses'> decided to play b6c8
# stockfish: b6c4
#
#
# ITERAÇÃO=81
#
#
# ITERAÇÃO=82
# The King nominated <class 'Horses.Horses'> to play!
# 	 the <class 'Horses.Horses'> decided to play c8b6
# stockfish: c1b2
#
#
# ITERAÇÃO=83
#
#
# ITERAÇÃO=84
# The King nominated <class 'Horses.Horses'> to play!
# 	 the <class 'Horses.Horses'> decided to play b6c8
# stockfish: f1e2
# 		 the <class 'Horses.Horses'> chose an invalid play b6c8
# 	 the <class 'Horses.Horses'> decided to play b6a8
# stockfish: f1e2
# 		 the <class 'Horses.Horses'> chose an invalid play b6a8
# 	 the <class 'Horses.Horses'> decided to play b6a4
# stockfish: f1e2
# 		 the <class 'Horses.Horses'> chose an invalid play b6a4
# 	 the <class 'Horses.Horses'> decided to play b6d7
# stockfish: f1e2
# 		 the <class 'Horses.Horses'> chose an invalid play b6d7
# 	 the <class 'Horses.Horses'> decided to play
# stockfish: f1e2
# 		 the <class 'Horses.Horses'> chose an invalid play
# 	 the <class 'Horses.Horses'> decided to play
# stockfish: f1e2
# 		 the <class 'Horses.Horses'> chose an invalid play
# 	 the <class 'Horses.Horses'> decided to play
# stockfish: f1e2
# 		 the <class 'Horses.Horses'> chose an invalid play
# 	 the <class 'Horses.Horses'> decided to play
# stockfish: f1e2
# 		 the <class 'Horses.Horses'> chose an invalid play
# 	 the <class 'Horses.Horses'> decided to play b6`7
# stockfish: f1e2
# 		 the <class 'Horses.Horses'> chose an invalid play b6`7
# 	 the <class 'Horses.Horses'> decided to play
# stockfish: f1e2
# 		 the <class 'Horses.Horses'> chose an invalid play
# 	 the <class 'Horses.Horses'> decided to play
# stockfish: f1e2
# 		 the <class 'Horses.Horses'> chose an invalid play
# 	 the <class 'Horses.Horses'> decided to play
# stockfish: f1e2
# 		 the <class 'Horses.Horses'> chose an invalid play
# 	 the <class 'Horses.Horses'> decided to play b6c4
# stockfish: f1e2
# 		 the <class 'Horses.Horses'> chose an invalid play b6c4
# 	 the <class 'Horses.Horses'> decided to play b6d5
# stockfish: f1e2
# 		 the <class 'Horses.Horses'> chose an invalid play b6d5
# 	 the <class 'Horses.Horses'> decided to play
# stockfish: f1e2
# 		 the <class 'Horses.Horses'> chose an invalid play
# 	 the <class 'Horses.Horses'> decided to play b6`5
# stockfish: f1e2
# 		 the <class 'Horses.Horses'> chose an invalid play b6`5
# The King nominated <class 'Queen.Queen'> to play!
# 	 the <class 'Queen.Queen'> decided to play d1f3
# stockfish: f1e2
# 		 the <class 'Queen.Queen'> chose an invalid play d1f3
# 	 the <class 'Queen.Queen'> decided to play d1e2
# stockfish: f1e2
#
#
# ITERAÇÃO=85
#
#
# ITERAÇÃO=86
# The King nominated <class 'Queen.Queen'> to play!
# 	 the <class 'Queen.Queen'> decided to play e2g4
# stockfish: b6d5
#
#
# ITERAÇÃO=87
#
#
# ITERAÇÃO=88
# The King nominated <class 'Queen.Queen'> to play!
# 	 the <class 'Queen.Queen'> decided to play g4i6
# stockfish: b6d5
# 		 the <class 'Queen.Queen'> chose an invalid play g4i6
# 	 the <class 'Queen.Queen'> decided to play g4h5
# stockfish: b6d5
#
#
# ITERAÇÃO=89
#
#
# ITERAÇÃO=90
# The King nominated <class 'Queen.Queen'> to play!
# 	 the <class 'Queen.Queen'> decided to play h5i6
# stockfish: b6d5
# 		 the <class 'Queen.Queen'> chose an invalid play h5i6
# 	 the <class 'Queen.Queen'> decided to play h5g6
# stockfish: b6d5
#
#
# ITERAÇÃO=91
#
#
# ITERAÇÃO=92
# The King nominated <class 'Queen.Queen'> to play!
# 	 the <class 'Queen.Queen'> decided to play g6g7
# stockfish: b6d5
#
#
# ITERAÇÃO=93
#
#
# ITERAÇÃO=94
# The King nominated <class 'Queen.Queen'> to play!
# 	 the <class 'Queen.Queen'> decided to play g7f6
# stockfish: g7h8
#
#
# ITERAÇÃO=95
#
#
# ITERAÇÃO=96
# The King nominated <class 'Queen.Queen'> to play!
# 	 the <class 'Queen.Queen'> decided to play f6f7
# stockfish: b6d5
#
#
# ITERAÇÃO=97
#
#
# ITERAÇÃO=98
# The King nominated <class 'Queen.Queen'> to play!
# 	 the <class 'Queen.Queen'> decided to play f7e6
# stockfish: b6d5
#
#
# ITERAÇÃO=99
#
#
# ITERAÇÃO=100
# The King nominated <class 'Queen.Queen'> to play!
# 	 the <class 'Queen.Queen'> decided to play e6e7
# stockfish: b6d5
#
#
# ITERAÇÃO=101
#
#
# ITERAÇÃO=102
# The King nominated <class 'Queen.Queen'> to play!
# 	 the <class 'Queen.Queen'> decided to play e7d6
# stockfish: f1d3
#
#
# ITERAÇÃO=103
#
#
# ITERAÇÃO=104
# The King nominated <class 'Queen.Queen'> to play!
# 	 the <class 'Queen.Queen'> decided to play d6d7
# stockfish: f1d3
#
#
# ITERAÇÃO=105
#
#
# ITERAÇÃO=106
# The King nominated <class 'Queen.Queen'> to play!
# 	 the <class 'Queen.Queen'> decided to play d7c6
# stockfish: f1d3
#
#
# ITERAÇÃO=107
#
#
# ITERAÇÃO=108
# The King nominated <class 'Bishops.Bishops'> to play!
# 	 the <class 'Bishops.Bishops'> decided to play f1e2
# stockfish: f1d3
#
#
# ITERAÇÃO=109
#
#
# ITERAÇÃO=110
# The King nominated <class 'Bishops.Bishops'> to play!
# 	 the <class 'Bishops.Bishops'> decided to play e2f3
# stockfish: e1d1
#
#
# ITERAÇÃO=111
#
#
# ITERAÇÃO=112
# The King nominated <class 'Bishops.Bishops'> to play!
# 	 the <class 'Bishops.Bishops'> decided to play f3g4
# stockfish: a1b1
#
#
# ITERAÇÃO=113
#
#
# ITERAÇÃO=114
# The King nominated <class 'Bishops.Bishops'> to play!
# 	 the <class 'Bishops.Bishops'> decided to play g4h5
# stockfish: a1b1
#
#
# ITERAÇÃO=115
#
#
# ITERAÇÃO=116
# The King nominated <class 'Bishops.Bishops'> to play!
# 	 the <class 'Bishops.Bishops'> decided to play h5g4
# stockfish: a1b1
#
#
# ITERAÇÃO=117
#
#
# ITERAÇÃO=118
# The King nominated <class 'Bishops.Bishops'> to play!
# 	 the <class 'Bishops.Bishops'> decided to play g4f3
# stockfish: c2c3
#
#
# ITERAÇÃO=119
#
#
# ITERAÇÃO=120
# The King nominated <class 'Bishops.Bishops'> to play!
# 	 the <class 'Bishops.Bishops'> decided to play f3g4
# stockfish: a1b1
#
#
# ITERAÇÃO=121
#
#
# ITERAÇÃO=122
# The King nominated <class 'Bishops.Bishops'> to play!
# 	 the <class 'Bishops.Bishops'> decided to play g4f3
# stockfish: a1b1
#
#
# ITERAÇÃO=123
#
#
# ITERAÇÃO=124
# The King nominated <class 'Bishops.Bishops'> to play!
# 	 the <class 'Bishops.Bishops'> decided to play c1a3
# stockfish: a1b1
#
#
# ITERAÇÃO=125
#
#
# ITERAÇÃO=126
# The King nominated <class 'Bishops.Bishops'> to play!
# 	 the <class 'Bishops.Bishops'> decided to play a3b4
# stockfish: a1b1
#
#
# ITERAÇÃO=127
#
#
# ITERAÇÃO=128
# The King nominated <class 'Bishops.Bishops'> to play!
# 	 the <class 'Bishops.Bishops'> decided to play b4c5
# stockfish: a1b1
#
#
# ITERAÇÃO=129
#
#
# ITERAÇÃO=130
# The King nominated <class 'Bishops.Bishops'> to play!
# 	 the <class 'Bishops.Bishops'> decided to play c5b4
# stockfish: a1b1
#
#
# ITERAÇÃO=131
#
#
# ITERAÇÃO=132
# The King nominated <class 'Bishops.Bishops'> to play!
# 	 the <class 'Bishops.Bishops'> decided to play b4c5
# stockfish: a1b1
#
#
# ITERAÇÃO=133
#
#
# ITERAÇÃO=134
# The King nominated <class 'Bishops.Bishops'> to play!
# 	 the <class 'Bishops.Bishops'> decided to play c5b4
# stockfish: a1b1
# interactive(children=(IntSlider(value=0, description='m', max=135), Output()), _dom_classes=('widget-interact'…
